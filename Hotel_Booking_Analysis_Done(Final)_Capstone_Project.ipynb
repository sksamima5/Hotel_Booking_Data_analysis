# %% [markdown]
# <a href="https://colab.research.google.com/github/sksamima5/Hotel_Booking_Data_analysis/blob/main/Hotel_Booking_Analysis_Done(Final)_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %% [markdown]
# ![indian-hotels.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Mounting Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Importing Essential Libraries

# %%
# Importing essential Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # CSV file location

# %%
file_path= "/content/drive/MyDrive/Capstone project (Hotel booking) /Hotel Bookings.csv"

# %% [markdown]
# # Reading Data

# %%
# reading csv file
df= pd.read_csv(file_path)

# %% [markdown]
# #Data Exploration

# %%
#checking the Data shape (rows and columns number)
print(f' The total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
#  The total 119390 rows and 32 columns.

# %%
#First 5 rows
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#Last 5 rows
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
#The min, max values,mean values etc. NAN values for mean, 25% , 50%, 75%, max indicates those are categorical columns.
df.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
#The data types for all the non-null entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ##Data Description
#
#
# 1. **hotel**: Hotel(Resort Hotel or City Hotel)
#
# 2. **is_canceled** : Value indicating if the booking was canceled (1) or not (0)
#
# 3. **lead_time** : Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
# 4. **arrival_date_year** : Year of arrival date
#
# 5. **arrival_date_month** : Month of arrival date
#
# 6. **arrival_date_week_number** : Week number of year for arrival date
#
# 7. **arrival_date_day_of_month** : Day of arrival date
#
# 8. **stays_in_weekend_nights** : Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9. **stays_in_week_nights** : Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10. **adults** : Number of adults
#
# 11. **children** : Number of children
#
# 12. **babies** : Number of babies
#
# 13. **meal** : Type of meal booked. Categories are presented in standard hospitality meal packages
#
# 14. **country** : Country of origin.`
#
# 15. **market_segment** : Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 16. **distribution_channel** : Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
#
# 17. **is_repeated_guest** : Value indicating if the booking name was from a repeated guest (1) or not (0)
#
# 18. **previous_cancellations** : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. **previous_bookings_not_canceled** : Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. **reserved_room_type** : Code of room type reserved. Code is presented instead of designation for anonymity reasons.
#
# 21. **assigned_room_type** : Code for the type of room assigned to the booking.
#
# 22. **booking_changes** : Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
#
# 23. **deposit_type** : Indication on if the customer made a deposit to guarantee the booking.
#
# 24. **agent** : ID of the travel agency that made the booking
#
# 25. **company** : ID of the company/entity that made the booking or responsible for paying the booking.
#
# 26. **days_in_waiting_list** : Number of days the booking was in the waiting list before it was confirmed to the customer
#
# 27. **customer_type** : Type of booking, assuming one of four categories
#
# 28. **adr** : Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. **required_car_parking_spaces** : Number of car parking spaces required by the customer
#
# 30. **total_of_special_requests** : Number of special requests made by the customer (e.g. twin bed or high floor)
#
# 31. **reservation_status** : Reservation last status, assuming one of three categories
#
# * **Canceled** – booking was canceled by the customer
#
# * **Check-Out** – customer has checked in but already departed
#
# * **No-Show** – customer did not check-in and did inform the hotel of the reason why
#
# 32. **reservation_status_date** : Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel

# %%
# Creating a copy of our dataset
df1=df.copy()

# %%
# Print columns name list
print(list(df1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# converting object type to datetime
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ##Data cleaning

# %%
# checking for all the Duplicate rows
# True indicates the Duplicate rows 
# False indicates the Different rows

df1.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Visualizing through Countplot Graph
plt.figure(figsize = (10,10))
sns.countplot(x = df1.duplicated())

# %% [markdown]
# ###We have 31994 Duplicate Rows in the Dataset so, we need to Drop all the duplicate rows

# %%
#Droping all the Duplicate data 

df1 = df1.drop_duplicates()

df1.shape
# Out:
# (87396, 32)

# %%
#Checking for Null Values
df1.isna().sum().sort_values(ascending = False).reset_index().rename(columns={'index':'All the Columns',0:'Zero values'})
# Out:
#                    All the Columns  Zero values
# 0                          company        82137
# 1                            agent        12193
# 2                          country          452
# 3                         children            4
# 4               reserved_room_type            0
# 5               assigned_room_type            0
# 6                  booking_changes            0
# 7                     deposit_type            0
# 8                            hotel            0
# 9           previous_cancellations            0
# 10            days_in_waiting_list            0
# 11                   customer_type            0
# 12                             adr            0
# 13     required_car_parking_spaces            0
# 14       total_of_special_requests            0
# 15              reservation_status            0
# 16  previous_bookings_not_canceled            0
# 17               is_repeated_guest            0
# 18                     is_canceled            0
# ...

# %% [markdown]
# ##So we Have Null values in columns- Company, agent, Country, children.
#
# for company and agent I will fill the Missing values with 0
# for country I will fill Missing values with object 'Others'. ( assuming while collecting data country was not found so user selected the 'Others' option.)
# As the count of missing values in Children Column is only 4, so we can replace with 0 considering no children.

# %%
# Filling/replacing null values with 0.

null_columns =  ['agent', 'company','children']
for col in null_columns:
  df1[col].fillna(0, inplace = True)

df1['country'].fillna('others', inplace = True)

# %%
#All The Null Values

df1.isna().sum().sort_values(ascending = False).reset_index().rename(columns = {'index':'All the Columns',0:'Zero values'})
# Out:
#                    All the Columns  Zero values
# 0                            hotel            0
# 1                      is_canceled            0
# 2               reservation_status            0
# 3        total_of_special_requests            0
# 4      required_car_parking_spaces            0
# 5                              adr            0
# 6                    customer_type            0
# 7             days_in_waiting_list            0
# 8                          company            0
# 9                            agent            0
# 10                    deposit_type            0
# 11                 booking_changes            0
# 12              assigned_room_type            0
# 13              reserved_room_type            0
# 14  previous_bookings_not_canceled            0
# 15          previous_cancellations            0
# 16               is_repeated_guest            0
# 17            distribution_channel            0
# 18                  market_segment            0
# ...

# %%
#Droppping all 166 those rows in which addtion of adults, children and babies is 0.

df1.drop(df1[df1['adults']+df1['children']+df1['babies']==0].index, inplace=True)

# %%
#Lets add new columns

df1['total_people'] = df1['adults'] + df1['babies'] + df1['children']   
df1['total_stay'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']

# %%
#The final rows and columns
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# #**Now Let's do some Exploratory Data Analysis**

# %% [markdown]
# #  **Univariate Analysis**

# %% [markdown]
# ##1) Which type of Hotels is mostly prefered by the guests?

# %%
df1['hotel'].value_counts()
# Out:
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
# Visualising by the pie chart.
df1['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)   
plt.title('Pie Chart for Most Preffered Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered Hotel')

# %% [markdown]
# ##Observation
# ##City hotels are mostly prefered by the guests as compare to Resort hotels.

# %% [markdown]
# ##2) Which Agent made the most bookings?

# %%
#Highest bookings made by agents
highest_bookings= df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

#taking top 15 bookings made by agent
top_fifteen_highest_bookings=highest_bookings[:15]

top_fifteen_highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 0      0.0          12141
# 14    14.0           3342
# 7      7.0           3294
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1493
# 8      8.0           1383
# 1      1.0           1228
# 6      6.0           1117
# 39    40.0            986
# 228  314.0            844
# 176  242.0            722
# 73    83.0            614

# %%
#Visualizaing the graph

plt.figure(figsize=(10,8))
sns.barplot(x=top_fifteen_highest_bookings['agent'],y=top_fifteen_highest_bookings['Most_Bookings'],order=top_fifteen_highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ##**Observation**
# ##Agent ID no. 9 made the Highest number of bookings

# %% [markdown]
# ##3) What is the Percentage of repeated guests in each hotels ?

# %%
df1['is_repeated_guest'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)   
plt.title('Pie Chart for repeated guest')
# Out:
# Text(0.5, 1.0, 'Pie Chart for repeated guest')

# %% [markdown]
# ##**Observation**:
# #Repeated guests are very Low which is only 3.9 %

# %% [markdown]
# ##4) What is the pecentage of cancellation?

# %%
df1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)   
plt.title('Pie Chart for Cancellation and non-cancellation')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Cancellation and non-cancellation')

# %% [markdown]
# ##**Observation**:
# #0 Denotes for not canceled
#
# #1 Denotes for canceled
#
# #**The percentage of cancellation is 27.5%**

# %% [markdown]
# ##5) Which type of food is mostly preferred by the guests in Hotels?
#
# ---

# %%
df1['meal'].value_counts()
plt.figure(figsize=(18,8))
sns.countplot(x=df1['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# ##**Observation**
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
#
# ###**So the most preferred meal type by the guests is BB( Bed and Breakfast)**
# ### **HB- (Half Board) and SC- (Self Catering) are equally preferred.**

# %% [markdown]
# #6) Which type of Room is mostly preferred by the guests in Hotels?

# %%
#Mostly preferred type of rooms
df_1 = df1['reserved_room_type'].value_counts().reset_index().rename(columns={'index':'room_type','reserved_room_type':'count'})

# %%
#plotting the graph
plt.figure(figsize=(12,6))
df_1.set_index('room_type').plot(kind ='bar',color='g')
plt.ylabel('Bookings')
# Out:
# Text(0, 0.5, 'Bookings')

# %% [markdown]
# #**Observation**
# #Almost 98.7% of the guests prefer ‘No deposit’ type of criterion while  booking hotels
# #Room type ‘A’ is most preferred by the guests second most preferred is ‘D’.

# %% [markdown]
# #7) From which countries the most guests are coming ?

# %%
country_df1 = df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:20]

# Visualizing by plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df1['country'],y=country_df1['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# #8) In which month most of the bookings happened ?

# %%
#groupby arrival_date_month and taking the hotel count
bookings_by_months_df=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Bookings"})

#Create list of months
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

#creating df which will map the order of months list without changing its value.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)

#sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

# %%
bookings_by_months_df
# Out:
#    arrival_date_month  Bookings
# 4             January      4685
# 3            February      6083
# 7               March      7489
# 0               April      7900
# 8                 May      8344
# 6                June      7756
# 5                July     10043
# 1              August     11242
# 11          September      6682
# 10            October      6921
# 9            November      4973
# 2            December      5112

# %%
#Visualisation by ploting graph
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Bookings'])
plt.title('Number of bookings across each month')
plt.xlabel('Month')
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##**Observation**
# In July and August had the most Bookings because of Summer vaccations.

# %% [markdown]
# #9) What is the percentage of booking changes made by the customers ?

# %%
booking_changes_df=df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_of_booking_changes",'booking_changes':'Counts'})

#Visualization by ploting the graph
plt.figure(figsize=(12,8))
sns.barplot(x=booking_changes_df['number_of_booking_changes'],y=booking_changes_df['Counts']*100/df1.shape[0])
plt.title("% of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# ##**Observation**
#
# ##Almost 82% of the bookings were not changed by guests.

# %% [markdown]
# #10) What is the percentage distribution of "Customer Type" ?

# %%
df1['customer_type'].value_counts().plot.pie(explode=[0.05]*4,shadow=True,autopct='%1.1f%%',figsize=(12,8),fontsize=15,labels=None)


labels=df1['customer_type'].value_counts().index.tolist()
plt.title('% Distribution of Customer Type')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **1. Contract**
# > When the booking has an allotment or other type of contract associated to it
#
# **2. Group**
# > When the booking is associated to a group
#
# **3. Transient**
# > When the booking is not part of a group or contract, and is not associated to other transient booking
#
# **4. Transient-party**
# > When the booking is transient, but is associated to at least other transient booking
#
# ### **Observation:**
# ### Transient customer type is more which is 82.4 % but the percentage of  Booking associated by the Group is very low which is 0.6%

# %% [markdown]
# # **Bivariate and Multivariate Analysis**

# %% [markdown]
# #1) Which Hotel type has  the Highest ADR?

# %%
#Groupby hotel

group_by_hotel = df1.groupby('hotel')

# %%
#groupby hotel adr
highest_adr = group_by_hotel['adr'].mean().reset_index()

#setting plot size
plt.figure(figsize=(10,8))

#setting labels
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title("Avg ADR of each Hotel type")

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])

# %% [markdown]
# ### **Observation**
# ### City hotel has the highest ADR, That means city hotels are generating more revenue than the resort hotels. More the ADR more is the revenue.

# %% [markdown]
# # 2) Which hotel type has the more lead time?

# %%
#groupby avg lead time

avg_lead_time = group_by_hotel['lead_time'].mean().reset_index()

#setting plt size
plt.figure(figsize=[10,8])

#setting labels
plt.xlabel('Hotel type')
plt.ylabel('lead_time')
plt.title('Avg lead time for each Hotel type')

#ploting barplot Graph
sns.barplot(x=avg_lead_time['hotel'], y = avg_lead_time['lead_time'])

# %% [markdown]
# ###**Observation**
# ###Resort hotels has slightly  high avg lead time. That means customers plan their trips on early note.

# %% [markdown]
# #3) ADR across the different month.

# %%
#groupby arrival_date_month and taking the hotel mean
bookings_by_months_df=df1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

#Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

#creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)

#sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

# %%
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
#setting plot size
#plotting the line
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

#setting lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# #**Observations**
# #Most number of hotel bookings are made for the month of August and the least is made for January.

# %% [markdown]
# #4) Which hotels has longer waiting time ?

# %%
#groupby hotel and taking mean of days in waiting list
waiting_time_df=df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
# waiting_time_df

#setting the plot size
plt.figure(figsize=(10,8))

# plot barplots
sns.barplot(x=waiting_time_df['hotel'],y=waiting_time_df['days_in_waiting_list'])

#setting the labels
plt.xlabel('Hotel type')
plt.ylabel('waiting time')
plt.title("Waiting time for each hotel type")
# Out:
# Text(0.5, 1.0, 'Waiting time for each hotel type')

# %% [markdown]
# ###**Observation**
# ###The City Hotel has longer waiting period than the Resort Hotels. Thus we say that City Hotels are much busier than the Resort Hotels.

# %% [markdown]
# # 5) Which Hotels has the most repeated guests ?

# %%
#Lets take repeated guest = 1
#Lets tske not repeated guest = 0
#groupby hotel
repeated_guests_df=df1[df1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})



#set plot size and plot barplot
plt.figure(figsize=(10,8))
sns.barplot(x=repeated_guests_df['hotel'],y=repeated_guests_df['number_of_repated_guests'])

# set labels
plt.xlabel('Hotel type')
plt.ylabel('Number of repeated guests')
plt.title("Most repeated guests for each hotel")
# Out:
# Text(0.5, 1.0, 'Most repeated guests for each hotel')

# %% [markdown]
# #**Observation**
# ###Resort Hotel has slightly more repeated guests than the City Hotels.

# %% [markdown]
# #6) Booking analysis according to months and years

# %%
#Finding out whcih month has the highest booking for the past few years
Month_wise_traffic_in_past_years = df1.groupby(['arrival_date_year','arrival_date_month'])['hotel'].count().unstack()
Month_wise_traffic_in_past_years
# Out:
# arrival_date_month   April  August  December  February  January    July  \
# arrival_date_year
# 2015                   NaN  2447.0    1975.0       NaN      NaN  1672.0
# 2016                3767.0  4415.0    3137.0    2799.0   1849.0  3842.0
# 2017                4133.0  4380.0       NaN    3284.0   2836.0  4529.0
#
# arrival_date_month    June   March     May  November  October  September
# arrival_date_year
# 2015                   NaN     NaN     NaN    1662.0   2694.0     2834.0
# 2016                3515.0  3826.0  3777.0    3311.0   4227.0     3848.0
# 2017                4241.0  3663.0  4567.0       NaN      NaN        NaN

# %%
colour_list = ['crimson','violet','blue','yellow','brown','grey','cyan','gold','green','pink','olive','teal']
plt.rcParams['figure.figsize'] = (20,8)
Month_wise_traffic_in_past_years.plot(kind ='bar' , color = colour_list)
plt.ylabel('No:of bookings')
plt.title("Booking analysis according to Months and years")
# Out:
# Text(0.5, 1.0, 'Booking analysis according to Months and years')

# %% [markdown]
# #Observation :
#
# #1.   August and July are the only two months in the given three years where there always has been bookings
# #2.   2016 saw the largest number of hotel bookings among the given three years

# %% [markdown]
# #7) Which distribution channel contributed more to adr in order to increase  the income ?

# %%
#groupby distribution channel and hotel
distribution_channel_df=df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

#setting plot size and plot barchart
plt.figure(figsize=(14,10))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# * Corporate - These are corporate hotel booking companies which makes bookings
# possible.
# * GDS -A GDS is a worldwide computerised network system between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live products, prices and availability data to travel agents and online booking engines, and allows for automated transactions.
# * Direct - Means that bookings are directly made with the respective hotels.
# * TA/TO - Means that bookings are made through travel agents or travel operators.
# * Undefined - Bookings are undefined. May be customers made their bookings on arrival.

# %% [markdown]
# #8) Which distribution channel has the Highest cancellation rate?

# %%
 #selecting the cancelled bookings
 df_cancelled = df1[df1['is_canceled']==1]

#groupby distribution channel
df_cancelled = df_cancelled.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})


#setting plot size and plot barchart 
plt.figure(figsize=(14,10))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data=df_cancelled)
plt.xlabel('Distribution channel')
plt.ylabel('counts')
plt.title('Cancellation Rate Vs Distribution channel')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Distribution channel')

# %% [markdown]
# ### **Observation**
#
# * In "TA/TO", City hotels has the highest cancellation rate compared to resort
# hotels.
# * Both in "Corporate and direct" the hotels has almost same cancellation rate.

# %% [markdown]
# #9) Which Market Segment has the Highest cancellation rate ?

# %%
 #selecting cancelled bookings
df_market_segment=df1[df1['is_canceled']==1] 
df_market_segment=df_market_segment.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})
df_market_segment
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      54
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     263
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     887
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1257
# 10  Offline TA/TO  Resort Hotel     800
# 11      Online TA    City Hotel   12615
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
#setting plotsize and plot barchart
plt.figure(figsize=(20,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= df_market_segment)

#setting labels
plt.xlabel('Market segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs Market segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Market segment')

# %% [markdown]
# ### **Observation**
# ### 'Online T/A' has the highest cancellation in both type of Hotels
# ##**In order to reduce the booking cancellations, hotels need to set the refundable/no refundable and deposit policies.**

# %% [markdown]
# #Correlation of the columns

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df1.corr(),annot=True)
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ##Observation
#
# ###1. lead_time and total_stay is positively corelated.That means more is the stay of customers more will be the lead time.
# ###2. is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are more likely to not cancel their bookings
# ###3. adults,childrens and babies are corelated to each other. That means more the people more will be ADR.

# %% [markdown]
# #ADR relationship with total number of people

# %%
plt.figure(figsize=(10,8))
df2=df1[df1['total_people'] < 6]
df3= df2[df2['adr'] < 5000]
##as there was an outlier with high value, we removed that for better visualization
sns.boxplot(x=df3['total_people'],y=df3['adr'])

#setting lables
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# ##Observation
#
# ###As the  total number of people increases ADR also increases.
# ###Thus ADR and total people are directly proportional to each other.

# %% [markdown]
# #Relationship between ADR and total stay.

# %%
#Groupby ADR, total stay, hotel
adr_vs_stay = df1.groupby(['total_stay', 'adr','hotel']).size().reset_index().rename(columns={0:'count'})
adr_vs_stay
# Out:
#        total_stay     adr         hotel  count
# 0               0    0.00    City Hotel    231
# 1               0    0.00  Resort Hotel    360
# 2               1    0.00    City Hotel    392
# 3               1    0.00  Resort Hotel     91
# 4               1    1.00    City Hotel      1
# ...           ...     ...           ...    ...
# 21987          48    0.00    City Hotel      1
# 21988          56   25.50  Resort Hotel      1
# 21989          56   28.79  Resort Hotel      1
# 21990          60  110.50  Resort Hotel      1
# 21991          69  110.00  Resort Hotel      1
#
# [21992 rows x 4 columns]

# %%
#plot line chart
plt.figure(figsize=(16,8))
#sns.lineplot(x='total_stay',y='adr',data=adr_vs_stay)
##There is an outlier here as well so we use 'df3' for the visualization
sns.scatterplot(y = 'adr', x = 'total_stay', data = df3)
plt.title('Relationship between adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# ##Observation
#
# ##We can see that as length of total stay or duration of stay increases the ADR decreases. This means for longer stay, customer has a chance of finalizing a better deal.

# %% [markdown]
# # **Conclusions:**

# %% [markdown]
# *	City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# * 	27.5 % bookings were got cancelled out of all the bookings.
# *	Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
# *	The percentage of 0 changes made in the booking was more than 82 %.  Percentage of Single changes made was about 10%.
# *	BB( Bed & Breakfast) is the most preferred  type of meal by the guests.
# *	Maximum number of guests were from Portugal, i.e. more than 25000 guests.
# *	Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
# *	Booking cancellation rate is high for City hotels which almost 30 %.
# *	Average lead time for resort hotel is high.
# *	Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
# *	Resort hotels have the most repeated guests.
# *	In July and August had the most Bookings because of Summer vaccations.
# * 'Online T/A' has the highest cancellation in both type of Hotels
# * In order to reduce the booking cancellations, hotels need to set the refundable/no refundable and deposit policies.
